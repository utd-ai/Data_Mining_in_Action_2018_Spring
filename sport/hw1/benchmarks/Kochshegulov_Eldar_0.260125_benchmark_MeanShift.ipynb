# %%
import pandas as pd
import numpy as np
import gc
import re
from sklearn.cluster import KMeans, MeanShift

# %%
city_replace = [
    ['peter|stpete|spb', 'SANKT-PETERBURG'],
    ['moscow|moskva|mosocw|moskow', 'MOSCOW'],
    ['novosib|nvsibr', 'NOVOSIBIRSK'],
    ['kater', 'EKATERINBURG'],
    ['n.*novg', 'NIZHNIY NOV'],
    ['novg', 'VEL.NOVGOROD'],
    ['erep', 'CHEREPOVETS'],
    ['rasnod', 'KRASNODAR'],
    ['rasno[yj]', 'KRASNOYARSK'],
    ['sama', 'SAMARA'],
    ['kazan', 'KAZAN'],
    ['soch[iy]', 'SOCHI'],
    ['r[yj]aza', 'RYAZAN'],
    ['arza', 'ARZAMAS'],
    ['podol.?sk', 'PODOLSK'],
    ['himki', 'KHIMKI'],
    ['rostov', 'ROSTOV'], # will ovveride Rostov-Na-Don later
    ['rostov.*do', 'ROSTOV-NA-DON'],
    ['ufa', 'UFA'],
    ['^orel|ory[oe]l', 'OREL'],
    ['korol', 'KOROLEV'],
    ['vkar', 'SYKTYVKAR'],
    ['rozavo|rzavo', 'PETROZAVODSK'],
    ['c.*abinsk', 'CHELYABINSK'],
    ['g omsk|^omsk', 'OMSK'],
    ['tomsk', 'TOMSK'],
    ['vorone', 'VORONEZH'],
    ['[yj]arosl', 'YAROSLAVL'],
    ['novoros', 'NOVOROSSIYSK'],
    ['m[yie]t[yi]s', 'MYTISHCHI'],
    ['kal..?ga', 'KALUGA'],
    ['perm', 'PERM'],
    ['volgog|volgrd', 'VOLGOGRAD'],
    ['kirov[^a-z]|kirov$', 'KIROV'],
    ['krasnogo', 'KRASNOGORSK'],
    ['^mo\W+$|^mo$', 'MO'],
    ['irk', 'IRKUTSK'],
    ['balashi', 'BALASHIKHA'],
    ['kaliningrad', 'KALININGRAD'],
    ['anap', 'ANAPA'],
    ['surgut', 'SURGUT'],
    ['odin[tc]', 'ODINTSOVO'],
    ['kemer', 'KEMEROVO'],
    ['t[yuio].?men', 'TYUMEN'],
    ['sarat', 'SARATOV'],
    ['t[uoy]u?la', 'TULA'],
    ['bert', 'LYUBERTSY'],
    ['kotel', 'KOTELNIKI'],
    ['lipet', 'LIPETSK'],
    ['leznodor', 'ZHELEZNODOROZ'],
    ['domod', 'DOMODEDOVO'],
    ['br[yji][a]nsk|braynsk', 'BRYANSK'],
    ['saransk', 'SARANSK'],
    ['znogor', 'ZHELEZNOGORSK'],
    ['smol', 'SMOLENSK'],
    ['sevolo', 'VSEVOLOZHSK'],
    ['p[uy].*kino', 'PUSHKINO'],
    ['re..?tov', 'REUTOV'],
    ['kursk|koursk', 'KURSK'],
    ['belgorod', 'BELGOROD'],
    ['r[yj]azan', 'RYAZAN'],
    ['solnechno', 'SOLNECHNOGORS'],
    ['utorovsk', 'YALUTOROVSK'],
    ['tver', 'TVER'],
    ['barn', 'BARNAUL'],
    ['to.?l..?.?tt[iy]', 'TOLYATTI'],
    ['i[zjg].?evsk', 'IZHEVSK']
]

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %% [markdown]
# #### <font color = 'blue'> Считываем данные</font>

# %%
df = pd.read_csv('data/test_set.csv', sep =',')
# Out:
# C:\Users\m1ckyro5aololo\Anaconda2\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (1,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(5)
# Out:
#      amount atm_address  atm_address_lat  atm_address_lon        city country  \
# 0  2.211818         NaN              NaN              NaN  IVANTEEVKA     RUS
# 1  1.331379         NaN              NaN              NaN  IVANTEEVKA     RUS
# 2  2.608004         NaN              NaN              NaN    PUSHKINO     RUS
# 3  1.916752         NaN              NaN              NaN  IVANTEEVKA     RUS
# 4  1.981067         NaN              NaN              NaN      MOSCOW     RUS
#
#    currency                       customer_id    mcc  \
# 0     643.0  00fd410f5c580c8351cafa88d82b60f3  5,411
# 1     643.0  00fd410f5c580c8351cafa88d82b60f3  4,111
# 2     643.0  00fd410f5c580c8351cafa88d82b60f3  5,411
# 3     643.0  00fd410f5c580c8351cafa88d82b60f3  5,411
# 4     643.0  00fd410f5c580c8351cafa88d82b60f3  5,814
#
#                                          pos_address  pos_address_lat  \
# 0       2-1 TOLMACHEVA STRIVANTEEVKA141280    RUSRUS        55.967487
# 1            SOVETSKIJ, 32IVANTEEVKA141282    RUSRUS        55.971296
# 2      105,KRASOARMEYSKOE SHPUSHKINO141206    RUSRUS        56.016591
# 3  G. IVANTEEVKA, UL.TOLMACHEVA, D.6IVANTEEVKA141...        55.964507
# 4           5 KOMSOMOLSKAYA SQMOSCOW101000    RUSRUS        55.776802
#
#    pos_address_lon                       terminal_id transaction_date
# 0        37.913682  ff0476dae4b098a7b16aabe93d4268df       2017-08-24
# 1        37.905184  7cfd9a60282459d4692ecc85b856072e       2017-08-12
# 2        37.909098  7e5a532f0029861d8a9c4f0479b9450b       2017-06-17
# 3        37.937912  2afe7d1bc61b86c449f413bdf2119032       2017-08-12
# 4        37.657352  ab4f00601ff1d949afc59ee3f804c79c       2017-04-26

# %% [markdown]
# #### <font color = 'blue'> Удаляем транзакции без даты</font>

# %%
df.drop(df[df['transaction_date'].isnull()].index, axis = 0, inplace = True)

# %% [markdown]
# ####  <font color = 'blue'> Приводим названия городов к более менее стандартным</font>

# %%
len(list(df.city.unique()))
# Out:
# 7445

# %%
df['city'] = df['city'].str.strip()

# %%
df['city'].value_counts().head()
# Out:
# MOSCOW           266704
# SANKT-PETERBU    158346
# MOSKVA           147708
# NOVOSIBIRSK       24219
# EKATERINBURG      23998
# Name: city, dtype: int64

# %%
for city in city_replace :
    #print(city[0], city[1])
    #df['city'] = df['city'].apply(lambda x : re.sub(city[0], city[1], str(x).lower())).str.strip()
    df['city'] = df['city'].apply(lambda x : city[1] if re.search(city[0], str(x).lower()) else x)

# %%
df['city'].value_counts().head()
# Out:
# MOSCOW             447091
# SANKT-PETERBURG    257498
# NOVOSIBIRSK         26806
# NIZHNIY NOV         25698
# EKATERINBURG        25209
# Name: city, dtype: int64

# %% [markdown]
# #### <font color = 'blue'>Объединим данные геолокации банкоматов и пос-терминалов (не самый лучший код)</font>

# %%
def f_atm(x) :
    if np.isnan(x['atm_address_lat']) or np.isnan(x['atm_address_lon']) :
        return 1
    else :
        return 0
def f_pos(x) :
    if np.isnan(x['pos_address_lat']) or np.isnan(x['pos_address_lon']) :
        return 1
    else :
        return 0

# %%
def f_lat(x) :
    if x['pos'] == 0 :
        return x['pos_address_lat'] 
    else :
        return x['atm_address_lat'] 
def f_lon(x) :
    if x['pos'] == 0 :
        return x['pos_address_lon'] 
    else :
        return x['atm_address_lon']

# %%
df['atm'] = df.apply(f_atm, axis = 1)
df['pos'] = df.apply(f_pos, axis = 1)
df['lat'] = df.apply(f_lat, axis = 1)
df['lon'] = df.apply(f_lon, axis = 1)
df['lat'] = df.apply(f_lat, axis = 1)
df['lon'] = df.apply(f_lon, axis = 1)

# %%
df = df[~df['lat'].isnull()]

# %% [markdown]
# #### <font color = 'blue'> Зачастую наблюдаем ситуацию когда у клиентов транзакции проводятся в разных городах. Поэтому у каждого клиента оставим только те города в которых совершено наибольшее число транзакций </font>

# %%
df['count'] = 1

# %%
df[['customer_id', 'city', 'count']].groupby(['customer_id', 'city'], as_index = False).count().head(10)
# Out:
#                         customer_id           city  count
# 0  00021683ccb416637fe9a4cd35e4606e    NOVOSIBIRSK     78
# 1  0002d0f8a642272b41c292c12ab6e602     ESSENTOUKI      2
# 2  0002d0f8a642272b41c292c12ab6e602      ESSENTUKI     19
# 3  0002d0f8a642272b41c292c12ab6e602  ESSENTUKSKAYA     32
# 4  0002d0f8a642272b41c292c12ab6e602   PREDGORNYIIY     24
# 5  0004d182d9fede3ba2534b2d5e5ad27e          SOCHI    120
# 6  0008c2445518c9392cb356c5c3db3392        SARATOV     22
# 7  0008c2445518c9392cb356c5c3db3392    UST-KURDYUM      1
# 8  0008c2445518c9392cb356c5c3db3392       ZONALNYY      1
# 9  000b373cc4969c0be8e0933c08da67e1  BAZARNYE MATA      2

# %%
df_customer_city = df.groupby(['customer_id', 'city'], as_index = False)['count'].count()

# %%
map_customer_city = {}
for cust in df_customer_city['customer_id'].unique() :
    tmp = df_customer_city[df_customer_city['customer_id'] == cust].sort_values('count', ascending = False).iloc[0]['city']
    map_customer_city[cust] =  tmp

# %%
map_customer_city
# Out:
# {'00021683ccb416637fe9a4cd35e4606e': 'NOVOSIBIRSK',
#  '0002d0f8a642272b41c292c12ab6e602': 'ESSENTUKSKAYA',
#  '0004d182d9fede3ba2534b2d5e5ad27e': 'SOCHI',
#  '0008c2445518c9392cb356c5c3db3392': 'SARATOV',
#  '000b373cc4969c0be8e0933c08da67e1': 'DZERZHINSK',
#  '000c589e94c95984721de4b2bfb9ee4e': 'NOVOIVANOVSKO',
#  '001611e3ac051a0ec91c88bbd9dbeb5a': 'IVANOVO',
#  '001691ae3885e80add35148a01e75206': 'SANKT-PETERBURG',
#  '002044159304738ea7e3598131809851': 'TOLYATTI',
#  '0026319faa345a573522f0a04f5c55bb': 'RYAZAN',
#  '0029d9be3692701efe66741fa74a8f8b': 'PODOLSK',
#  '002c40ec938e91de248400dec824bd49': 'MOSCOW',
#  '00317c648bc11161417b342ad480e724': 'SANKT-PETERBURG',
#  '0038ea686d27899b0942409157d04ff2': 'SURGUT',
#  '003bc1334379d480c7e5f28240dc40d9': 'MAGNITOGORSK',
#  '00450ac1c22c9ee6dda590ff5366236c': 'VORONEZH',
#  '00509465377a24375b276c5da9a67fa5': 'SANKT-PETERBURG',
#  '005b206d0ffec59e249e6f7adc1b2e83': 'MOSCOW',
#  '0069673252af134ecf00854d7ecaed5d': 'CHEREPOVETS',
#  '007c458cded5ba3b7b02fcfe8724e80b': 'UFA',
#  '007cf1e85db00eea3a958667b7e32fc9': 'MOSCOW',
#  '0088f5bf466ccf990e0773fd3255e887': 'SANKT-PETERBURG',
#  '008c9f725cf88093477cc5f7278a2351': 'IZHEVSK',
#  '008fe6ff2d4c530aee50c0446d55790e': 'SANKT-PETERBURG',
#  '00963fad786043b96ac74a1fca0a2da6': 'KRASNODAR',
#  '00a0973ba20bf9d1daafe1644b20dc8b': 'CHELYABINSK',
#  '00a9c3a172cfc6d2e0198da4c539b3c9': 'PODOLSK',
#  '00ad61328ea4906b9354155ca96227a3': 'MOSCOW',
#  '00baa0945c9a5905483c623286241204': 'SANKT-PETERBURG',
#  '00cb489f5903eed7c454b14f15b1144d': 'MERKULEVO',
#  '00d5f4597785639fbea644760fcdd56e': 'MOSCOW',
#  '00e0ea572b1542e80303e337069fd247': 'SANKT-PETERBURG',
#  '00e3681003cdaa589753d93b0df92e61': 'MOSCOW',
#  '00f5a40ccd506b5f36789b7009aaab58': 'SANKT-PETERBURG',
#  '00fd410f5c580c8351cafa88d82b60f3': 'IVANTEEVKA',
#  '0105249fde93ead403ee2d015511b73a': 'SAMARA',
#  '0106b669d5d10148c16ea81890b9d511': 'KIROV',
#  '010799d30fab651676520e20ff6dd22c': 'MOSCOW',
#  '01097e0bcfe7e25e3a1e21d53fcde472': 'MOSCOW',
#  '010d01dd3f8ed4c98aa0ea6be89c4303': 'MOSCOW',
#  '010dfcfff325443fe8e52765a204c472': 'MOSCOW',
#  '01184b37d8b929d8c08ecd38135864cb': 'MOSCOW',
#  '011e0a79cc27491e73431b428b69292f': 'KRASNOYARSK',
#  '011f80f85def7bc4e5eb8f4e23e67bc0': 'KALININGRAD',
#  '012253ab27fe11202cd3bf3d06400426': 'SANKT-PETERBURG',
#  '0124939ab7dc640a041644cec4a97731': 'MOSCOW',
#  '01342ead1829eec3dca380bbb91c8fc8': 'VOLGOGRAD',
#  '01349ec3288adbf114dc4f4633af6610': 'SANKT-PETERBURG',
#  '0136e0082861106f3a80878115446365': 'CHEREPOVETS',
#  '01428e38cc904df2b6cbed46e612b1e4': 'MOSCOW',
#  '01480f0a495212838d6a963e6a3bf1c9': 'MOSCOW',
#  '014ed72aea0c3aceb029adb18d8a9b5d': 'OREL',
#  '0154cc5ed0618b973ca05a8bdb183923': 'SANKT-PETERBURG',
#  '0154f2dcb1ef536a9395862eaf7d0d2c': 'IRKUTSK',
#  '0156715c96095172c171c3f3ee943a3b': 'MOSCOW',
#  '01579358128d532496ea283897c01310': 'OREL',
#  '015e6138f7b991d8f450312b3721f5b4': 'MOSCOW',
#  '0166258a6f9e7591148ad119573cd3bc': 'EKATERINBURG',
#  '01677b908e299a1a5aff0eb7d6db55ac': 'MOSCOW',
#  '016870800d4d728ae8369bc77b601b88': 'MOSCOW',
#  '0175c595d9114b2b1baa41465c8aad9c': 'SANKT-PETERBURG',
#  '017686c762d6204748f2bf95a718e2ac': 'STAVROPOL',
#  '017c653d4d2912eb4057c01348d1559e': 'SANKT-PETERBURG',
#  '017e5f15c9c96445a0d3298edf244df1': 'NIZHNIY NOV',
#  '0187d474be5985ee08b47ffe6d8471ff': 'MOSCOW',
#  '01903915b8823ec2122f0dc958743057': 'MOSCOW',
#  '019172423acba9eac0a73431e4646335': 'MOSCOW',
#  '019ab70c53284f98b633b8dd4725b2c0': 'MOSCOW',
#  '01a3e3f4619f2d6cb8144aeac6447807': 'SANKT-PETERBURG',
#  '01a62b6642c9857ce63aefcbfd98c575': 'MOSCOW',
#  '01af8fd39e55e5051aab7040c4cc7253': 'MOSCOW',
#  '01b2a4ffff9c41001ce9a075d87dc8eb': 'KRASNODAR',
#  '01b7e6014bbdaed0c45e1a0ba47de780': 'UFA',
#  '01ba65ad76905b14be5e37d394b2484a': 'VOLZHSKIY',
#  '01bcd3ec54a6f7f26ed4428c69a8c421': 'MOSCOW',
#  '01c0642661ccaa2cfdee2f5741128dc2': 'MOSCOW',
#  '01c4c5ac9fe73c0d3a05e2ce1510f023': 'MOSCOW',
#  '01c78bb18a2d41dcadbfc80b1d9c804d': 'NIZHNIY NOV',
#  '01cab20cbdd54e05cd41eb501dd0f6dc': 'MOSCOW',
#  '01d25afd67eec0f0ca2c6746b4e2ed94': 'SANKT-PETERBURG',
#  '01dd11d12be651d9a5129ea15ad45318': 'MOSCOW',
#  '01f58b3ec222f953cc2e272f28be2fa5': 'SANKT-PETERBURG',
#  '02014e4ae830f85f41dd313f5d166321': 'SANKT-PETERBURG',
#  '02017ee944b7b46f6237df423bd231b6': 'MOSCOW',
#  '020d1a57dca7d31e8462f2a88c80c214': 'MOSCOW',
#  '020e734442e90b5e8c300dd38a477fc9': 'MOSCOW',
#  '021abb302632cee71a104612f943c439': 'SANKT-PETERBURG',
#  '021b825d811c418762db72973ba4ce2c': 'NOVOROSSIYSK',
#  '021fe928a82fb77021bfd20074322e01': 'KALUGA',
#  '022130a29f2165301b37dad38b9ac1c0': 'MOSCOW',
#  '0226c9b47e596ad2c130bda4645d63f3': 'ROSTOV',
#  '023a1ea323af70d1bf2188656b4de09b': 'CHEREPOVETS',
#  '023bacff3122321480354b9b779f16af': 'SANKT-PETERBURG',
#  '024a4a0f435ae796a9b88f3764a70f8a': 'SANKT-PETERBURG',
#  '024d263dfa7fb4f6636f6f91b47a6fa9': 'MOSCOW',
#  '0251fa382bfe59e6491acb1f21748bd6': 'MOSCOW',
#  '025316f8e69b78aec8fb097a33a5b016': 'MOSCOW',
#  '0254f8df611bfa01df26d391bbd21841': 'KLIN',
#  '02668b3b6b4e78096b31e6510eeb7129': 'EKATERINBURG',
#  '026c803388221f3d57073f1465e44f26': 'MOSCOW',
#  '026cfa8c8ec1c3e153ec979f36ed2929': 'MOSCOW',
#  '026dcadfee9944609a11c5cf55109b57': 'ZHELEZNODOROZ',
#  '02744ac6c128756ce1bd270746778ca1': 'PODOLSK',
#  '027553f0fa8803158841cd3118156bc3': 'CHEREPOVETS',
#  '027a2b8b454b9e15145622c24b6c98c8': 'SANKT-PETERBURG',
#  '027f1b087eba96ba240e71025906b661': 'SANKT-PETERBURG',
#  '027fefbafc92e7fec351fa658a61bd0f': 'MOSCOW',
#  '028a8d5b177bb8e3b2423ce15f096fb4': 'ZVENIGOROD',
#  '02956cea60cf3c9d552bf489112ff811': 'SANKT-PETERBURG',
#  '029f2a86b9ac7641f3d7ecbaa79bf27a': 'EKATERINBURG',
#  '02a02f1b2e0a3dac8d8345478c87105f': 'MOSCOW',
#  '02a6f78a97864942a6904dc5433ece0d': 'MOSCOW',
#  '02a86ed15a32669a0ec882c9361ae209': 'MOSCOW',
#  '02ae42d929785cbde5dfa84b06fe24ea': 'CHEREPOVETS',
#  '02b47a8c9892ad013a3091ca0fbf3afd': 'MOSCOW',
#  '02d7f924b94bb157410bcdb4b1256eae': 'MOSCOW',
#  '02df65eb4c057e439bb7dc4a85edf336': 'KALUGA',
#  '02e22241493daa6a1e5f0ef6ba488165': 'KAZAN',
#  '02e2d118ac67af9b4fd68bad80be8b7b': 'MOSCOW',
#  '02e6fa409350f53c2331fa55fd6d2306': 'KIROV',
#  '02e887a27ad9857f9f9eac01375b0743': 'MOSCOW',
#  '02f04561ca750797739b2aea8191cc56': 'SAMARA',
#  '02f07efb90c56516238c4580a3c9c7f7': 'YAROSLAVL',
#  '02f308c7e5267e865dc5237c23b936c1': 'MOSCOW',
#  '02f3c515a45cf33cecf4f7f83a338df8': 'KHIMKI',
#  '02f94655bc6c57197c3903f2bc2eb45d': 'MOSCOW',
#  '02f9d992c27098e1b90f84e6dc9698aa': 'PERM',
#  '02fd93006c07b846705cb17642c7e332': 'SANKT-PETERBURG',
#  '02fe9a8ba58e9ad59e38383f7558670d': 'MOSCOW',
#  '0303062bc17e273f1ece45be0de89b89': 'NIZHNIY NOV',
#  '0308fc73e526d53f998257b66653598b': 'PERM',
#  '030e09231aab60c24630afe0b686fa7a': 'UFA',
#  '030e6df1f5fb7bf7876daab5cfc439f3': 'MOSCOW',
#  '0311ec93525c6d64d1d214642953ebfa': 'MOSCOW',
#  '0315c1d57503c39c3971214968ddc89e': 'MOSCOW',
#  '03171460949b52f8ea7767b458f26552': 'KIROV',
#  '031b61c7c88fbc0aebe5f413cbe9245f': 'SANKT-PETERBURG',
#  '031e234e65c860e04ddcea371eb867a8': 'MOSCOW',
#  '03246a0768b0236892188f7d625d369f': 'SANKT-PETERBURG',
#  '03281a46a193e24f56e59adeb85c18ea': 'KRASNOYARSK',
#  '033036b5f67ff9b97ad8614a1b9ceba3': 'MOSCOW',
#  '03312384bb0619c7abc44f372de46cf2': 'NIZHNIY NOV',
#  '033446a4ae35ba3a6faef7920a52f36d': 'MOSCOW',
#  '033b8243084812ead5b47434d0913c1d': 'MOSCOW',
#  '03472a0d64ebbd305e6f270ddfd5fc8c': 'MOSCOW',
#  '0348500cb738131181b3c6a685a4b151': 'SANKT-PETERBURG',
#  '035921f1f64dbbcc2a6e805a1b5d3433': 'MOSCOW',
#  '03618621a5ffc776fbe03c5a7f99a8c3': 'MOSCOW',
#  '036b960678f3995ebba490b02fcb4568': 'BELGOROD',
#  '0383ed5988dae368decc851ebee83ac2': 'KALININGRAD',
#  '03850de5411396b3dfcacd22082328c5': 'MOSCOW',
#  '03856495b7af7c095e98c0190ff68956': 'MOSCOW',
#  '03878129ccb7562d2f85c3f6d1f03684': 'SMOLENSK',
#  '03887a98f1ed8071d1d34ec28ed0ad07': 'PETROZAVODSK',
#  '038a3be56427b450c6089637ef9922b6': 'MOSCOW',
#  '038b1ed23cb05f73e54c497002dac12e': 'EKATERINBURG',
#  '03903f03d7019fc7a0df813a692e024d': 'KURSK',
#  '0395d71ba8c046d1ab81d3d4eb522279': 'NIZHNIY NOV',
#  '03a37ea195e014fa26060cb84fc7e26c': 'MOSCOW',
#  '03abd53e4f3e0cbf74a76b1ee4ba2e21': 'MOSCOW',
#  '03b6b0a58d5bc978e67dcf24385a67a5': 'KRASNOYARSK',
#  '03b883385bcfe682e41d510ec1a1dc5e': 'FRYAZINO',
#  '03b9f00f20fc673a587f11db7e7dd8c7': 'MOSCOW',
#  '03c152dac08f8675f0beec8a82a20110': 'MOSCOW',
#  '03c3d5db350fa69877df58b2b325c63a': 'SANKT-PETERBURG',
#  '03c9912a1e717063dc5724389898202a': 'SANKT-PETERBURG',
#  '03d04bb25fb5c0727f6f07ff2228e416': 'VSEVOLOZHSK',
#  '03d7ced073dba2be9a94245e8eb2cdc5': 'KRASNODAR',
#  '03dfe8497d6ac4e635ebc774162aad6a': 'SANKT-PETERBURG',
#  '03e3ec86e242646d8cee3104b0c8d70c': 'Dolgoprudnyy',
#  '03e7eed4895fa0ed1d36a3adf7826761': 'PAVLOVSKY POS',
#  '03f9d3b573ad14de6ec09986f117f596': 'MOSCOW',
#  '03faa58802a582ed28755cb67ff6da80': 'KRASNOYARSK',
#  '0405e8ba8f5dea687a391a1861350a8b': 'MOSCOW',
#  '04092059250eaa5bfc157f6b472613a7': 'KIROV',
#  '041704145c6a4c89aa51e4480426cc32': 'MOSCOW',
#  '041e1902514060090fa6e15c8427d03e': 'DOMODEDOVO',
#  '042e008a7a9496e5e09d13c459266757': 'MOSCOW',
#  '042f2978c9739b8ed7dba0aa24039c50': 'BALASHIKHA',
#  '042f39e5c639f98430429c80fe9307a7': 'SANKT-PETERBURG',
#  '0442d3fb33587d7a7b5e2e3d9a4c6218': 'EKATERINBURG',
#  '04497ab1eec430dd0396a13199f89edd': 'EKATERINBURG',
#  '044dcac3c1bfa2c1fb51266c989d8d24': 'MOSCOW',
#  '045197539559976bdf17b55ce866e71d': 'MOSCOW',
#  '0458eae563dc1357165df6bd4293b111': 'MOSCOW',
#  '045973626ad9ace8ad0da94b78c3e4ba': 'KOLPINO',
#  '045b52f3200a6429d3359362762d3cbe': 'SANKT-PETERBURG',
#  '045e760ed2e80e351f92540b56e9878c': 'MOSCOW',
#  '046418d9a85d098761ccd1a03ab7f591': 'SOCHI',
#  '046651bb7ac192e65b1e33c4708b8def': 'MOSCOW',
#  '0467c91be3825eb5204d78e7ea404e6b': 'SANKT-PETERBURG',
#  '046c3a782c9421c6bc845bb6b3776ce2': 'PETROZAVODSK',
#  '0472b0fcf31a83cf3c339346bdfe1197': 'SANKT-PETERBURG',
#  '047412845e4b96a5d27194aaac4fc338': 'SANKT-PETERBURG',
#  '0475a135ce729b7944c7c625ecd4aaad': 'SANKT-PETERBURG',
#  '0479b1bf677905d75592ad5a8f8c1386': 'SARANSK',
#  '048e2611ee7427931656183fc84c4f67': 'MOSCOW',
#  '0493fe5936e2d920eec71647ccee5abf': 'MOSCOW',
#  '0495a1c4d9fdfaf33cbbe51853a896f7': 'SANKT-PETERBURG',
#  '049756bca29f4a64ff029c339cd897b5': 'KRASNODAR',
#  '049917f8eca4e809019fbe872ddbfcb4': 'SANKT-PETERBURG',
#  '04a4cd258d8ab632cd826cced5cc5517': 'SANKT-PETERBURG',
#  '04b739989450f6f85325af8b89197cd2': 'MOSCOW',
#  '04bbde6e176601b6f331fffbdf2e1ce6': 'KINGISEPP',
#  '04be0d637a4d7a971275c341a2b3aee7': 'KALUGA',
#  '04c179b5048584b2b1eccf9458bd1870': 'KIROV',
#  '04c8d3bbb4ba5c0577dd689376a9e65f': 'KLIMOVSK',
#  '04c9530dd094c2bd8553b95890ffb5bd': 'MOSCOW',
#  '04ce65fb3128e3723e34369ad0c7a176': 'SANKT-PETERBURG',
#  '04d16958f9c54c906b283d964cb15757': 'MOSCOW',
#  '04d91e64995ec9f912f68a91e13c11bf': 'NOVOROSSIYSK',
#  '04dd31fc6d6eb46cd70c139c6a322a5d': 'REVDA',
#  '04dfd0b327ce845d469fdcef332408fa': 'NOVOSIBIRSK',
#  '04e35bbd8b78259a4dd9ed1e3830b416': 'NOVOSIBIRSK',
#  '04e3fc6f37b95e5a671e141b5f936859': 'MOSCOW',
#  '04f50c51428efa772425e17931a2a6cd': 'GOLITSYNO',
#  '04f5c09f1163d620a2e519cb92dd7b2b': 'MOSCOW',
#  '04f7760aad02a38620870c2169bbb409': 'MOSCOW',
#  '04fb68f5d45c4652cebd12afd7cd13d4': 'SANKT-PETERBURG',
#  '04fef5c1371785d46be8c0fc939bcf04': 'MOSCOW',
#  '05075fda5d7bb3039ebffdaddbdd412e': 'MOSCOW',
#  '051291376ea82fd9967b41efac7f4983': 'MOSCOW',
#  '051c99c5a5cc67b168cb4cb91f7c1c04': 'MOSCOW',
#  '052597e72cc573e30088ecb9c461b7d0': 'MOSCOW',
#  '0528a5c2071cdb78e6aa6cfe09581873': 'SADOVYY',
#  '052f17f2c60c864418bb0fe26fa5347f': 'EKATERINBURG',
#  '053ba9c4c594e0eb217ffb7d2801df5d': 'SCHERBINKA',
#  '05442e1864d9771663dde5cc36f304ca': 'ODINTSOVO',
#  '05526b2447ee621987e5830bd6db06a3': 'MOSCOW',
#  '0554c389a77e66c67e6664b1cad0aa4b': 'MOSCOW',
#  '055999d8c0b82dd284b7191b12035cdf': 'SOBINKA',
#  '055d74c2313e7d66974d8467f99d7b85': 'KAZAN',
#  '05600918ac9f5c14c1628bf85a580f26': 'CHELYABINSK',
#  '0560ccc1b1adef40c9cf7b2bce76307e': 'SHCHEGLOVO',
#  '056cb5c3765661766d02fda58e2d00d1': 'SANKT-PETERBURG',
#  '056e12fbcee69eac4fac693966267616': 'MOSCOW',
#  '057292863fbd739392a98b05fc35f2ef': 'KALININGRAD',
#  '058acb571c63b31747f34a894f96f809': 'KRASNODAR',
#  '059c9d09ef14f196a0f0d4929c62409e': 'MOSCOW',
#  '059fdd8a752b78bd4ea41d294991d768': 'MOSCOW',
#  '05a68c34149b6d8a69538a7cd232698d': 'KRASNODAR',
#  '05b557e76f202a6715f25b9b47f1a9e3': 'SANKT-PETERBURG',
#  '05ba17e3f5f4a6a3e6d0a40e0d3b9e71': 'ZHELEZNODOROZ',
#  '05bb2395c7b2c2eb26e689c4478ffc8c': 'SANKT-PETERBURG',
#  '05c37f72fec2e9ca9cf0bf6b71f46aa2': 'APRELEVKA',
#  '05c4b16124c62e89f837aabccd2cf528': 'MOSCOW',
#  '05cb01bedf1c8f5c03ff8b751e071ff3': 'NOVOSIBIRSK',
#  '05d3af3d1acbd112614b940ed7b54263': 'KRASNODAR',
#  '05d900b12653fb805ef4f196fe9e08b6': 'NOVOROSSIYSK',
#  '05e18a505bbe40f7b649c88023144cdb': 'ROSTOV',
#  '05e40d6e939e741b5aef3febf918ab63': 'BOR',
#  '05e47f580c012feaa5a58521485a5ebb': 'MOSCOW',
#  '05e6aa47e5e9b58811fdb62059a59f81': 'MOSCOW',
#  '05fedb63b550feb3394db7a11584ad80': 'UFA',
#  '06035cf872e8c8a207ddc70795b678ad': 'SANKT-PETERBURG',
#  '0608ac900efdfcb766d1a699db9993f0': 'MOSCOW',
#  '0609cfcef6aa186652cd89632ef2a2ea': 'CHEREPOVETS',
#  '060f5058dd76075a4be9a154b4be5fc8': 'MOSCOW',
#  '061189851091110a49b8c9f9705ce70c': 'SANKT-PETERBURG',
#  '062154a74dc6f0e7c35a4a24b7374502': 'MOSCOW',
#  '062cc7e0701a8a89139ac3dc2df0c97e': 'SMOLENSK',
#  '0638c67f404a0a33b6dff06a2847fa9e': 'ANAPA',
#  '064567b26e24d1ffbd3fa14646a5d180': 'GRYAZI',
#  '0654793808f80d373abc864ae1e329ce': 'MOSCOW',
#  '0657cb04af412402b04307b4218b3f7d': 'IRKUTSK',
#  '0659bd33e1b2714d3483390265b431dd': 'YAROSLAVL',
#  '065f12aec57ab57af14dbf4de15f4b4e': 'VORONEZH',
#  '06621432876ad1d6b3100990802b8220': 'SARATOV',
#  '0667c7b94c7a24738b3ac268bf52453b': 'MOSCOW',
#  '06681f22dcce5b5da52044e1d69f7876': 'SANKT-PETERBURG',
#  '066d5e5246a56268b88335679842bb2e': 'OREL',
#  '0671814ee67f7bd8796f3528d66246b5': 'MOSCOW',
#  '0677fd74df83702f198ee5701c56b692': 'TARASOVKA',
#  '067ad6695e8c14be88f95e6e8ae9fb89': 'MOSCOW',
#  '067fe6f6439fb7c6a540d2efbb0dcd74': 'SERPUKHOV',
#  '0680001a9e0ab3fc45d17990936de78e': 'NIZHNIY NOV',
#  '06858c269a388bebd7dc5649b4a472a5': 'MOSCOW',
#  '0685e814b68f8f1ef9122b82cc8bf198': 'MOSCOW',
#  '0691519c8eefa2c396b980285f2a3f10': 'MOSCOW',
#  '0694e6846613a99f54ef8acca8b6f5ee': 'MOSCOW',
#  '0697c963149ca17015f7dabbd4d4ba89': 'MOSCOW',
#  '069f28c9399361b83b400c8f21136d62': 'MOSCOW',
#  '06a5c1d547a8fc6621570b03320e9198': 'MOSCOW',
#  '06ad29ec976d0819a0bc75e137171d87': 'KRASNOYARSK',
#  '06b0b52d9cf7bc3fadce1b7e1ccbe948': 'KRASNODAR',
#  '06b165c692c9fb01bbdd1890e78408c2': 'MOSCOW',
#  '06b6e058000a8f2cb1e52c327515aa4b': 'KEMEROVO',
#  '06b9c370ce5467b352d565bfde0b5eab': 'SANKT-PETERBURG',
#  '06bc8a199b8adde107be50a4a6f2e46b': 'CHEREPOVETS',
#  '06c1cf0fd1200bbd8fb35cefa4ba3154': 'EKATERINBURG',
#  '06c58053753af3689f9fd6195f4c8508': 'SANKT-PETERBURG',
#  '06cbddf07a6343c995b7912b71bb8448': 'MYTISHCHI',
#  '06d32a50250ec91854ddf7e50ac5786b': 'SANKT-PETERBURG',
#  '06e0e0d98deaf7ae3f83fc12d8053c63': 'MOSCOW',
#  '06e2ef5424242e38eca825c612f5792e': 'MOSCOW',
#  '06e8112524b86d552ef337aa8fad9ef4': 'VSEVOLOZHSK',
#  '06f5465c68b8562e001fd15aac396600': 'VOLGOGRAD',
#  '06f975364c5ed19a1af1b93215dd681a': 'PERM',
#  '06fc4e594e16b3889cd2092f6cd72d8a': 'SANKT-PETERBURG',
#  '070aeaf297988f7a19fd26a05626a41c': 'SANKT-PETERBURG',
#  '070d3ca785584acceb90a7904caa862a': 'SANKT-PETERBURG',
#  '07135d1657d59ed66bffbc1c1b1f42f8': 'TULA',
#  '0715f6d4948df758e540e1a35e26ea0c': 'EKATERINBURG',
#  '071aa92dd88720e9964eababff64482e': 'NOVOSIBIRSK',
#  '071c0d9adc135857d2bb04c407286c88': 'CHELYABINSK',
#  '071eaeddab6ab33627e7383c2c8c1adc': 'NOVOSIBIRSK',
#  '072013c24aed144b0a0707166fed5db2': 'SANKT-PETERBURG',
#  '0723f2f61444b1563ff12a6bd371fffd': 'SANKT-PETERBURG',
#  '07256d1385556ff54ce256e7bf3a49fb': 'VIDNOE',
#  '07261e58664b3c4f911d91f028153e61': 'SANKT-PETERBURG',
#  '0732e9787efaf84db31bea952478aff8': 'KRASNOYARSK',
#  '0734ca151cf5d74fb688e04e78e8ba39': 'CHELYABINSK',
#  '0734f1256c21ef7c7b7f3455fbf4b42b': 'SANKT-PETERBURG',
#  '073adc24684b4673f3a3d654e4db65ce': 'MOSCOW',
#  '07407d19229ecfd643b4762c0ed3712f': 'MOSCOW',
#  '0742a6366d89210f6f8fa7d86bfdece2': 'MOSCOW',
#  '074652715668dc19f1452ddb13678478': 'MOSCOW',
#  '0748fab2a51ba3f37e5a072c50d88143': 'SHEBEKINO',
#  '07529dab1397095dd4b4948e73e3a062': 'SANKT-PETERBURG',
#  '0756e0fd7f837b669eaea33d4939f246': 'CHEREPOVETS',
#  '075bfdabefeb3a2817c32010f9150278': 'RAKHMANOVO',
#  '0766b448370710b6387b503f83ed2cea': 'MOSCOW',
#  '0766b6fd98581fcf7073069d1f026c30': 'SIVERSKIY',
#  '076bbff4e65d03cbfd8fa5d9f5873fd5': 'TOLYATTI',
#  '076e6bdc1084c1609bb6c0d7f2b45ef9': 'ELEKTROUGLI',
#  '0771db8bcdabea30b4e75e9436e07d6f': 'SANKT-PETERBURG',
#  '077409a8f9c23dfdebad6ccb5f26a841': 'SANKT-PETERBURG',
#  '077ec8e3a2927a5216a762771418c456': 'SANKT-PETERBURG',
#  '07876832857ece34444a8231f2f91883': 'SANKT-PETERBURG',
#  '0789136f2b659dffe8e3aa8955d9e88d': 'SOCHI',
#  '0792f34af4a45d5ef6f8f5ea371571c6': 'SANKT-PETERBURG',
#  '07936c8cc83ec41f6bdbb431d4c8fafd': 'MOSCOW',
#  '07a7460860ca5ea587039d84582edf3b': 'SANKT-PETERBURG',
#  '07ae8911763c78f68dc0da6cfa742b22': 'NIZHNIY NOV',
#  '07b1d7b7d7f8b488aa95ec991f5badcd': 'SANKT-PETERBURG',
#  '07bb6b22698efb2a4ba19cc4f41d0a1b': 'MOSCOW',
#  '07bc26e617431f1464ccb2a3532226fc': 'MOSCOW',
#  '07bdf4b36b69dab2896ee3dca3091471': 'SANKT-PETERBURG',
#  '07ca60bb4cf4b7e3d8a147835fccc345': 'KRASNOYARSK',
#  '07d71e48817363528c79367d80ae62a4': 'SANKT-PETERBURG',
#  '07db17dbba471572919315112ee8a841': 'MOSCOW',
#  '07dcd76477a6c328f342c27a0f3ba300': 'MOSCOW',
#  '07df4aa78e35ea6c2d80bfda8d0bfe9b': 'MOSCOW',
#  '07e958c80ff7536b089c3811976295f9': 'PUSHKINO',
#  '07eb50af5eb89b2bfc2764a719cc262d': 'SANKT-PETERBURG',
#  '07ee4fb6a5dcb6e786cc78a8834f10e9': 'MOSCOW',
#  '07f36c017bc64462afb6b39c9ec9cd2b': 'PETROZAVODSK',
#  '07fd297839451d0f285c259d5c5db11c': 'EKATERINBURG',
#  '080714928949df54ec2b65b804b0f9f3': 'LIPETSK',
#  '080fe4b2ffacff812de7ce79b32f2e4f': 'NOVOROSSIYSK',
#  '081561734737b31afd4a987f4833b91d': 'SANKT-PETERBURG',
#  '08184db6c2418c463539d78138e57eb5': 'SANKT-PETERBURG',
#  '0827246f7659ead10d8879bac7bd136a': 'SAMARA',
#  '0828e99f7096c74cc4badba4071bcc20': 'MOSCOW',
#  '0831dd9cc7bb0fb9e484a8fae3719cc8': 'SANKT-PETERBURG',
#  '0834a43e5ad85355a6c279919c23d9f2': 'KHIMKI',
#  '0840871715059ce38f7f346907720ac4': 'MOSCOW',
#  '0840b4695e85688554b32d732a0c5628': 'KAZAN',
#  '084a51ff91de7c10ed7e2058908877ce': 'MAGNITOGORSK',
#  '08607aea52e1a1b08c6411f6fbb2f911': 'NOVOSIBIRSK',
#  '0861eb0554f720b63281b8154447ef62': 'MOSCOW',
#  '086439f88ffc409fda98ec4f7e757f8b': 'SANKT-PETERBURG',
#  '0866ca048061670f4f102e37c011f018': 'VOLGOGRAD',
#  '086b41e1c2f5bdef49131a81fd764d5e': 'MOSCOW',
#  '086fd441441dd315614395d43110abb7': 'MOSCOW',
#  '087328375f56a4ae22fb1ea14d6e05da': 'MOSCOW',
#  '087ded21777a720ecba794010617abab': 'KRASNOGORSK',
#  '08851f8a153b03c9e7a8b30ea96bbf31': 'SANKT-PETERBURG',
#  '0885e544fd2321f98da6f8083246dfa3': 'MOSCOW',
#  '088f5d19a4a7239885fb6ab5bf8fbff6': 'MOSCOW',
#  '08925d3d3b99924da9b93ff28be74fa1': 'MOSCOW',
#  '0893fc437ae4483811ad992b2f8aab81': 'BELGOROD',
#  '0895529efac9821b05619fdfd11d7b5e': 'VOROTYNSK',
#  '0895dd8c09dc00a24673cd612e898b5f': 'MOSCOW',
#  '089ec8823a49e5cbda06f002f0042d15': 'MOSCOW',
#  '08a36a4890089a081ac67ac5c1a81f50': 'PUSHKINO',
#  '08a5bcb3c422d6677a028268ad97685c': 'SANKT-PETERBURG',
#  '08ba47823a2e60137aba956ea95f4a02': 'ASBEST',
#  '08c2438ea79aefcfde90d2cbacbe0112': 'PUSHKINO',
#  '08c7b5709967f87a26f97e1d17d6bfc0': 'MOSCOW',
#  '08cc246158363c423b37857c3f4fdbf9': 'MOSCOW',
#  '08d2b3a56b1c1b567cc7853812840852': 'MOSCOW',
#  '08d2bbea400ede369ec5eb183e4c1b4f': 'KURSK',
#  '08de9b31fbc342b59de06fa707ecbeaa': 'MOSCOW',
#  '08e2951a520e8c68b706e611e17d88d8': 'CHEREPOVETS',
#  '08ebcdc4d3cfce099db487b4faa48efc': 'MOSCOW',
#  '08ed03d57f6e956b7a179841bd277b40': 'EKATERINBURG',
#  '08f057ff93f9bd60251cb3ce8418e5aa': 'SANKT-PETERBURG',
#  '08f88c4c5cb32e3893786db4f90b4950': 'MOSCOW',
#  '090a1617e9eec3aa16bee972ad447a81': 'MOSCOW',
#  '090becfe63c9a93c03b324f962ca4ae9': 'MOSCOW',
#  '091032b99f1344e0138e4f166091aa13': 'MOSCOW',
#  '091ebcd3f286c26bc1abad70830c7ec6': 'MYTISHCHI',
#  '09280e61a6336acf7357d06a463b69cd': 'MOSCOW',
#  '0929b48fa0c5227afca4f5e155ccbb55': 'SANKT-PETERBURG',
#  '092c1d091d3eef46f0c5c9b20db3b3c0': 'MOSCOW',
#  '092fefa8b0fda724da1430aabc9a3017': 'MOSCOW',
#  '0930ab82c21bab1c55931cecaf2e6a2c': 'SANKT-PETERBURG',
#  '0930b8c9a7c388aa4e519efdb2397d8c': 'ANGARSK',
#  '09321d0ac0d712290521c62a98d0bafb': 'SANKT-PETERBURG',
#  '093f2d042b772ad1d23de1ae1b4f89e5': 'MOSCOW',
#  '09402fd3661ed03d488deaa0c0b0377e': 'UFA',
#  '09499be664151cef4bc1aa7f427a0a27': 'MOSCOW',
#  '095627783e2ba4ec766a446e13866d43': 'MOSCOW',
#  '0956ae059756a42fa3a2369e2b55c302': 'RAMENSKOE',
#  '0958687d307c70b036160ff7e48fbb1a': 'MOSCOW',
#  '0960e860ccc4e97ad526fe5f6840ab03': 'MOSCOW',
#  '096423fc97250da106f8cc704a6f9e30': 'SOCHI',
#  '09672cd7aaeacd0289fc552696871397': 'SANKT-PETERBURG',
#  '0967c239800d39285fb6c71876cbf237': 'MYTISHCHI',
#  '0974b60a5f3e8f825e71b7aba8e0cafb': 'KRASNOYARSK',
#  '0981898f5d86f16b1afbbacb60f50b03': 'MOSCOW',
#  '09872fec0bc66ee7bead8f48d7875a77': 'SANKT-PETERBURG',
#  '09921a08ed166ebb0c5cf9d6d62cc742': 'NOVOSIBIRSK',
#  '0996f0569d673f8fc589d640f3d6ed4b': 'SAMARA',
#  '09a30db1e76d8cb5fadcfd296d77357a': 'MOSCOW',
#  '09ab3353fba67ea28e41c1fe19f20ae9': 'VOLGOGRAD',
#  '09ab7333ddc09d735110f6eef6b49a91': 'OMSK',
#  '09b32be406b9494a618414eff198899c': 'MOSCOW',
#  '09b4f9bb679198f369918fa77f3ac34a': 'NOVOSIBIRSK',
#  '09bde6d72ce34096ff8cf1cec1bdd196': 'PODOLSK',
#  '09bfe728be83d3f2beea61c41afd2e34': 'MOSCOW',
#  '09c059e3a38057e11eb2f222889871a4': 'SANKT-PETERBURG',
#  '09c6734e48713c5c50feff694ea5e970': 'MOSCOW',
#  '09c83f24e2f8b401212b403e62487a83': 'ROSTOV',
#  '09ca8a3cd816f4bfba4f5e638d8c3c3b': 'MOSCOW',
#  '09d83763d6e70f6ab61b345daa7f20d7': 'PETROZAVODSK',
#  '09dc44b74965c8278fec1b1101cf128f': 'UFA',
#  '09dcdcbdc5909a2c2439fa237672c177': 'MOSCOW',
#  '09df0665e6b1735313673670d5ab091f': 'EKATERINBURG',
#  '09dfbc8a31ab94e2925bd8b666785847': 'MOSCOW',
#  '09e3a33bd3a15559212ac9a51d5709f3': 'OREL',
#  '09ed6a3c6b7bd2493230bb6c6cba135c': 'VOLGOGRAD',
#  '09f5e4ba191b0673320bbf640f471604': 'SANKT-PETERBURG',
#  '09faf1fbf3ac7160469e76e73dc3f15b': 'MOSCOW',
#  '09fd0128d9005a951283dbc46769b494': 'MOSCOW',
#  '09fe2b3ec765780c26cb315ec2226b7f': 'BRYANSK',
#  '0a0e5a31454d552d0ea837fbe906f5e3': 'IVANTEEVKA',
#  '0a1945dce575c6c723c1b95a4cdfba83': 'SANKT-PETERBURG',
#  '0a1f562addcd9ddd68f51cf66d814a3e': 'MOSCOW',
#  '0a266b6fb9ce639564a16a4c2954a4d4': 'MOSCOW',
#  '0a3ac0f1153cdf819ccd29354ebb4c9e': 'EKATERINBURG',
#  '0a3d774f99c14df0df3c1b9925b755af': 'SANKT-PETERBURG',
#  '0a5622c8b5d98c1a8a210073963006e8': 'MOSCOW',
#  '0a5f32082bbf6cc6ed8ffda5dbc90a96': 'SANKT-PETERBURG',
#  '0a60dd3c9d48164c17733efecd045d58': 'SANKT-PETERBURG',
#  '0a69eb85cc37887f320e7447b079cb6c': 'MOSCOW',
#  '0a82940e19a8b6db7059568ee221cbd5': 'CHELYABINSK',
#  '0a8a1305a1326768f23fde72da1876d2': 'NOVOPETROVSKO',
#  '0a91616eb20f2ee02a833e295e11266f': 'KRASNODAR',
#  '0a91d322c9618ab81793113128399e68': 'SANKT-PETERBURG',
#  '0a9b314b856cafa084ae43f79da1eeed': 'VORONEZH',
#  '0a9c78dfa971d698129fcabcf8f7a828': 'MOSCOW',
#  '0a9efb6244d1fd567c8db53977a5df2d': 'ANAPA',
#  '0aa169b898f3298b02534ec548f902bb': 'NOVOSIBIRSK',
#  '0aa495843a6447cc0532e3d94dea4408': 'KRASNOYARSK',
#  '0aa5d1c79ce111fc8ae79638293550e3': 'MOSCOW',
#  '0aa8c15f6f5949f1b88c695c2475c30c': 'MOSCOW',
#  '0aaa7152b06eb20d02bac3d22387cbe9': 'MOSCOW',
#  '0ab4837770f9d5d8e2ede9e422456fde': 'NOVOSIBIRSK',
#  '0abaf5717e73035aca26527e79ad913e': 'PERM',
#  '0abf17dc192fd201f5c76fc39b154ae1': 'ROSSOSH',
#  '0ac08dcd3a02d1b0ba5bec45b552923f': 'MOSCOW',
#  '0ac429847a97da57044cb54c56e00074': 'TROITSK',
#  '0ac9258bebbd8892a847281f792ff61d': 'MOSCOW',
#  '0acb7ff726e2a2fb1efc201fb6aef164': 'IRKUTSK',
#  '0ad39558251a28d365e943f7d66fd73f': 'MOSCOW',
#  '0ad70a0d3730bc98d439963785f12241': 'MOSCOW',
#  '0ae6c3c40751561f1fcce891c5c8e2ca': 'NIZHNIY NOV',
#  '0aedddda535e5d3739fefa9141ed85ad': 'CHELYABINSK',
#  '0aef5c7f17d337fe82b35f863a5df022': 'MOSCOW',
#  '0aefde9e1b2dc956d776e4938f467fcd': 'KIROV',
#  '0b04127a23adadcc6bbed3721a0a64d4': 'NOVOSIBIRSK',
#  '0b1057dd1a5b9577a72946e199f7a638': 'TULSKAYA REGI',
#  '0b1493d82a95f2227f15c0de7d3b0288': 'KRASNOYARSK',
#  '0b14f9a6c387a0cdedf76822bc478f38': 'SANKT-PETERBURG',
#  '0b196328172c48ceb59bfe16cbb2c6b1': 'MOSCOW',
#  '0b19da7f149179b4184462a781eb2234': 'MOSCOW',
#  '0b20110610cdcb4e082e3b60bdc63321': 'MOSCOW',
#  '0b206c9571daef9adbaf6c1cf32042eb': 'MOSCOW',
#  '0b26e6071ddbed3c89639093e8d6ccb5': 'NIZHNIY NOV',
#  '0b2ce9709ed9a266cfb1f07b1534b90d': 'MOSCOW',
#  '0b2e3a20fc95bab6db5c93774bdde006': 'NIZHNIY NOV',
#  '0b32c6166708d5d9d075a013fe91b1d1': 'SOCHI',
#  '0b381f23f883589a664bdbe1b36f2f0e': 'CHEREPOVETS',
#  '0b3a4d1ac08c1631aca3115035f9cc66': 'KSTOVO',
#  '0b3b1f3a3d59ba9ac1b6a128c3039972': 'SANKT-PETERBURG',
#  '0b3d27cfb0864c4241d1a8edd6e6fb00': 'MOSCOW',
#  '0b509060b10b05d16fada2e48417df85': 'SANKT-PETERBURG',
#  '0b511ade38fdf93528ee65cefa52900f': 'MOSCOW',
#  '0b51bd07e3e4ff538636a9234e9440b8': 'EKATERINBURG',
#  '0b531a351f859d33e20fe979f52306d0': 'SANKT-PETERBURG',
#  '0b5550fcdd0e3ff5773eb7a6ec7eda3b': 'NIZHNIY NOV',
#  '0b59e115c9d832d9529c03c03f3c5411': 'MOSCOW',
#  '0b616bf88bdc0c9c438277f25d238042': 'MOSCOW',
#  '0b6387d3a958143c860dc33faf68cb0d': 'KRASNODAR',
#  '0b677e4b717407e1b20194d99cbe20a0': 'MOSCOW',
#  '0b6fc491f53215089475d47a76e8c2ba': 'SANKT-PETERBURG',
#  '0b70a02e8c4a7d4bbb81939eb0bc8a6d': 'NOVOKUYBYSHEV',
#  '0b73711b843009aa26d2235db684b212': 'BERDSK',
#  '0b7e1ed91bb92bce3c45a3e42c8c4c83': 'MOSCOW',
#  '0b80348d3186772790cdfd9402a96c44': 'ODINTSOVO',
#  '0b80731e1bd61895163afeadc05d06bf': 'TULA',
#  '0b95383eead15525dcdb8b154a5d9864': 'MOSCOW',
#  '0b9e5a581f59f4196985be0661ffb6af': 'NOVOROSSIYSK',
#  '0ba7a979678c178b54eb100c9060ea65': 'SMOLENSK',
#  '0ba8a9ac8a781965ee797a1040756d36': 'SANKT-PETERBURG',
#  '0bb03ff0ab66288ecefc5a59cfc4c090': 'STARAYA KUPAV',
#  '0bb6d8d57570c802e4f773cd4845bd70': 'SANKT-PETERBURG',
#  '0bb7373769ca1cd59bcef546f3517e62': 'NIZHNIY NOV',
#  '0bb91fa4e8771a4f302bf4426e9b86e0': 'NIZHNIY NOV',
#  '0bb9b3d0eb7e9f9e161f3d29301b8439': 'SANKT-PETERBURG',
#  '0bcefca468935edf5a22c351f568af41': 'MOSCOW',
#  '0bd49aa757714e7f317e6184a1cfd849': 'MOSCOW',
#  '0bd7f4b2b6e9b1d58e6f8ad2bd04a17d': 'MOSCOW',
#  '0be3d1b3e118d6bed982e673f1f12023': 'MOSCOW',
#  '0bea418559bf807ea37168d7634d7411': 'LIPETSK',
#  '0beadb86ea5c9a196993095337ef7f3b': 'MOSCOW',
#  '0beb9e4e723397605f99d4f1e962f662': 'SAMARA',
#  '0bee824a8ec17c6c0f6df32463ee00fa': 'CHELYABINSK',
#  '0bee956f6bb31bdc2935740994143cbe': 'MOSCOW',
#  '0bef12293981453d4c7171755f1e2595': 'NIZHNIY NOV',
#  '0beffbf9d84d09dcbe2eb75398e39238': 'MOSCOW',
#  '0bf13d20de3fe1fb77c3eba4f09b369c': 'MOSCOW',
#  '0bf1927d8e8c28f45eee24cda086e2e0': 'UFA',
#  '0c03d96fa66941608f0e2142e8c47c7a': 'KRASNOYARSK',
#  '0c0e0c325df22ae464b5374201105ee4': 'SANKT-PETERBURG',
#  '0c0ef9f2a77543b5698f7f630015e50c': 'MOSCOW',
#  '0c13cc95889152f1c78429624b38af62': 'MOSCOW',
#  '0c1d181f5f25e146cbbf2a86948ff885': 'MOSCOW',
#  '0c3346b1f893ded12f480f85879cd5b4': 'OMSK',
#  '0c37629d84f65208c1e5006166385c74': 'MOSCOW',
#  '0c420e5fbca6c51e6ceb00d5faa63afd': 'SURGUT',
#  '0c47b03939bbbd3ad490a0a3c7e01655': 'LOBNYA',
#  '0c47b36b08464d295457a66f674a1cab': 'SANKT-PETERBURG',
#  '0c47b496d946f556972b0c8357946170': 'MOSCOW',
#  '0c4c5943b63b715a1a7c37afca887328': 'MOSCOW',
#  '0c4d4aafb46fef1913388c40eec7dd1c': 'YAROSLAVL',
#  '0c4f35269aa5b0947bf93aa9cb0df3f0': 'MOSCOW',
#  '0c5ce2cb8d3b9db787aed1322bee93ae': 'MOSCOW',
#  '0c6bede10fd1133c532ff27c2bd9428e': 'MOSCOW',
#  '0c6efecf12475e3505ebbe8b162d2096': 'KAZAN',
#  '0c6f1633615dc5b6866e9a12ddd8692d': 'SANKT-PETERBURG',
#  '0c783e78f4d1ae28052059eb743bf876': 'NIZHNIY NOV',
#  '0c7b8daab76b31ddfdce9e0d7f88ae8c': 'MOSCOW',
#  '0c8961a9d3c05aab7830e3b0b09609d9': 'NOVOSIBIRSK',
#  '0c8a081a35523507ffebc989b4cb9de9': 'PODOLSK',
#  '0c928d5757feca9b1c7b556cf029ac36': 'SAMARA',
#  '0ca56688d4f9f7bac47bcdb57be4f683': 'MOSCOW',
#  '0ca70e52f555bfe6824be14db2770e60': 'VOLGOGRAD',
#  '0ca74950d6ec7272e87e6730cd009f4f': 'MOSCOW',
#  '0cace4c62df58f1fc1f927bccd1ba910': 'SANKT-PETERBURG',
#  '0cae66b8a012158220be53718605cdfc': 'MOSCOW',
#  '0cb242ea4ac41de216319da6f951697c': 'CHEREPOVETS',
#  '0cb8dc067c76ef57b38c19473b8d57f1': 'VOSKRESENSK',
#  '0cbedf6f1f16cac90c2524dea9f63a00': 'MOSCOW',
#  '0cc14e99ac3e453e554622ee499645ea': 'NOVOROSSIYSK',
#  '0cc1f701f8bb0f019b719882a837b403': 'SANKT-PETERBURG',
#  '0cc33406583601b813a9c3328ade230a': 'SANKT-PETERBURG',
#  '0ccad4fc8b365145d3d6f78257e8df8f': 'SANKT-PETERBURG',
#  '0ccae0b7eba54e1c5ae239ae911dff19': 'SANKT-PETERBURG',
#  '0ccd2d0933dfbb76fd7e9ae0317a4d1d': 'SANKT-PETERBURG',
#  '0ccf791c72238eab4d0d3133a79f5ea2': 'SMOLENSK',
#  '0ccfde042db004503f8774441100923f': 'MOSCOW',
#  '0cdfda1f2ae376e0acb6b5a36109eb3b': 'ATEPTSEVO',
#  '0ce566c4ad748172ae69e9c19358c85f': 'MOSCOW',
#  '0ce8a19b03889c69a754236804b424aa': 'KRASNODAR',
#  '0cebd5e2ba176005a798e37d5b7bc4e3': 'MOSCOW',
#  '0cf9f5e46ac0c0356bf126668b73449e': 'MOSCOW',
#  '0cfb7a0fe3d40b5ea5bec023ad5bdb31': 'SANKT-PETERBURG',
#  '0d05a20a88a11e8d4ab1f139992c0992': 'ANAPA',
#  '0d0ff51991e39500b7e966a35eee62ff': 'SOCHI',
#  '0d10a968617f5798048e6a24088087d9': 'MOSCOW',
#  '0d173fea4e565096ccf653852846858f': 'SANKT-PETERBURG',
#  '0d1b5336a5763dd0aa183e9ff8ac92ce': 'SANKT-PETERBURG',
#  '0d1c2d0faffcee31cd0c790a148dcb63': 'EKATERINBURG',
#  '0d224d64f679410713f584aa296c23fe': 'BRYANSK',
#  '0d22755409bad1bdd653212e416b60a7': 'MOSCOW',
#  '0d22e1cbf39f4b0e15d161819773eaed': 'MOSCOW',
#  '0d23ae3b0757af7c133314256fd7fac1': 'NOVOROSSIYSK',
#  '0d2a44c184a71b8c2a768125ff9eba54': 'EKATERINBURG',
#  '0d35309ced4cbaff5c1fa711c7ad9e11': 'SANKT-PETERBURG',
#  '0d40b2bfe0422d93f12f3fe76ee27b00': 'SMOLENSK',
#  '0d449680e68e28c52bde7d685b628d72': 'SANKT-PETERBURG',
#  '0d4e04dccf69e15d4e3c4a03c78d6cdb': 'SANKT-PETERBURG',
#  '0d50cf6dad9ddd2a77d8c0b5761baf0e': 'KRASNOYARSK',
#  '0d57000b7a9845dfdd37e666857f65c3': 'MOSCOW',
#  '0d5d75a839e86ddf3a6364fd68143090': 'MOSCOW',
#  '0d628bcf447356b5f9eefdc328f5f31a': 'NOVOROSSIYSK',
#  '0d7ba0e8a7d44b16aa860a0a9aada732': 'FEDOROVSKIY',
#  '0d85ed2993cf49491653b146b910691b': 'DOMODEDOVO',
#  '0d8692268fcee367f275ecb9705b2618': 'SANKT-PETERBURG',
#  '0d8b435dfc610ed455a1302f4d22c522': 'MOSCOW',
#  '0d939f162928acdf5add311111de3d59': 'MOSCOW',
#  '0d97d69e0c74fea2f9f6a404657bcaf4': 'SANKT-PETERBURG',
#  '0d99e7001e1d692b5c253b03d13e0568': 'EKATERINBURG',
#  '0da092319dcfa563200d52f83e97b0aa': 'SANKT-PETERBURG',
#  '0dac83235654a63a1d37555b9fef5344': 'MOSCOW',
#  '0db333c70e4f6fdaecfee0cfac01e669': 'NIZHNIY NOV',
#  '0dbef7e6818b33b51c1347457087ee44': 'MOSCOW',
#  '0dc3d7c5b2a438da066107b6a78c48d6': 'SANKT-PETERBURG',
#  '0dd28dc68454db2edcc1b54d1ac5cd96': 'SANKT-PETERBURG',
#  '0deaeea2319a24e64bbe3a99c901f13d': 'KRASNOYARSK',
#  '0deb2d4e746399e53d525170256a8f3d': 'SURGUT',
#  '0df5b7d51ec31252b0bca2ce30d1984e': 'MOSCOW',
#  '0df76ee97b8a446a2b17c9f06f9a5ad0': 'MOSCOW',
#  '0df8f87eda2df8e4d938f96dd83db60c': 'KAZAN',
#  '0dfe438c6ee33ea2077220ded61b272f': 'MOSCOW',
#  '0e013161f76e3e1d17513b9b5d961412': 'MOSCOW',
#  '0e0192e956007e4390fcfdc77cebdb02': 'SANKT-PETERBURG',
#  '0e035415ad359bc290af4b4c25111f91': 'KEMEROVO',
#  '0e0386911ab96cd5723a183d3c1aec80': 'SANKT-PETERBURG',
#  '0e1773a5ffb11314b0e113b8c22d6dba': 'MOSCOW',
#  '0e1847323e819519d4ebcb1dd535b163': 'SAMARA',
#  '0e1a859eb8eae98459eba9b2dd926dce': 'SANKT-PETERBURG',
#  '0e1b3ec75dd2fb1aceefd46c031ab43b': 'SANKT-PETERBURG',
#  '0e278a8022ef80d3f2f6892216b7f467': 'CHEREPOVETS',
#  '0e45f5f3fc84405c2a7a832f0fcc5353': 'MOSCOW',
#  '0e469e7cf6eb4e6db4cb63e19d999ad1': 'KHIMKI',
#  '0e581604d2f1cc2b81044bdec18a3c41': 'MOSCOW',
#  '0e592beb1d248fac0284223194f554a5': 'MOSCOW',
#  '0e5fe854ec51528c252633c620c68af8': 'KRASNODAR',
#  '0e75f810e27f0ef0de2ae0b59435d63d': 'PODOLSK',
#  '0e7ce43a04bd80bbafbc5c07ae31e272': 'MOSCOW',
#  '0e8c66d4dd4c6246f15fa9092138ec4d': 'KRASNODAR',
#  '0e8e4f8b66cf97f4918618d0a10f6fab': 'NIZHNIY NOV',
#  '0e8e8aa30fddf3cb56aa323cbaabaf60': 'MOSCOW',
#  '0e92a746662cea21ed580dcf6ee14c70': 'SANKT-PETERBURG',
#  '0e92c87c19be7e8d7c266f17c33c7828': 'SANKT-PETERBURG',
#  '0e9543ecca255ecbe41c3564115f4a90': 'UFA',
#  '0e9671d9357afcede12047956c5688de': 'ROSTOV',
#  '0e9771da49f3666724a079e0f86f07f8': 'SANKT-PETERBURG',
#  '0ea2cd868047e2225a14d3e46467f8c3': 'SANKT-PETERBURG',
#  '0ea7b5d57ddb7e20d9aaac16a2ca04ea': 'KALININGRAD',
#  '0ead5ed1de5f972ba5924c51fe444992': 'MOSCOW',
#  '0eb35a3054a0bf927d5fcc15dc12526b': 'SANKT-PETERBURG',
#  '0eb9427fc152a08747803dd76033a142': 'SANKT-PETERBURG',
#  '0ec17dcac21c8a7d9e66c94f3da06755': 'SANKT-PETERBURG',
#  '0ec3e87a44f0e1c56a0de507688c3559': 'SANKT-PETERBURG',
#  '0ec7408211bd00910f1776a5c46286e9': 'ODINTSOVO',
#  '0eccf26fd90f8ebc3aa7195226035691': 'NOVOSIBIRSK',
#  '0ecd4dc2a75e2b900e69a44692c964fd': 'MOSCOW',
#  '0ed2f27f84b33d4d62a71256785291a8': 'KAZAN',
#  '0ee4d47b1899699c8d9f75578575b8dc': 'ROSTOV',
#  '0ee53f5200ad86ed4ff59cd93796dd44': 'MOSCOW',
#  '0ee94772744fb6979f22fdf08784e5be': 'MOSCOW',
#  '0ef05ab29e8e4b79caaa580a63bcc2d7': 'SANKT-PETERBURG',
#  '0efbb2aa5457a56b358ddca6fa2b32be': 'VORONEZH',
#  '0effaf1fc4d0a0d6406b09e37d6ba47b': 'NIZHNIY NOV',
#  '0f04560080bbc161f75f3b21722a956f': 'SANKT-PETERBURG',
#  '0f083d1f30631b4588c7b6df901ac683': 'SANKT-PETERBURG',
#  '0f0b186a01aa7aeeeadb860c13f1cd9f': 'KRASNOYARSK',
#  '0f0d2e0ff5ce8d073afe566e36256a50': 'TULA',
#  '0f148b7cc11c67041fc41ac2cd3b6e60': 'SANKT-PETERBURG',
#  '0f18acbcafb236ab4041b9cfc675ba70': 'MOSCOW',
#  '0f213a2466b081a28c67ecc15026a7ae': 'NOVORIZHSKOE',
#  '0f29ffca00ef4b091bbc7bd69ca8963b': 'MOSCOW',
#  '0f39558cb42ca38405ec923e3f008763': 'MOSCOW',
#  '0f3d2ad9b41f175fec001db755d2527a': 'MOSCOW',
#  '0f44416f1c352eb7c99d6b77c8be6c22': 'MYTISHCHI',
#  '0f454466a3752d22ef60da2f38c95446': 'MAMONOVO',
#  '0f495f7fcd4255333a3db5f11dde6e84': 'LIPETSK',
#  '0f4aa5bf45f26513f410086efb218129': 'NOVOSIBIRSK',
#  '0f4c7c4ffa0b371bd96ed18931b21778': 'SANKT-PETERBURG',
#  '0f4d9b435104164c243e76eac0d60258': 'MOSCOW',
#  '0f540a4867ce0544903bfbeaf63e4f30': 'KRASNOYARSK',
#  '0f65a4cb79d56629cdf63cdeb0c0376f': 'SERPUKHOV',
#  '0f681f1d9a093a9253b93642e1b44b79': 'SANKT-PETERBURG',
#  '0f767a0c35c161121d02b0344bb1acab': 'SAMARA',
#  '0f788a2caa6e84b9f14f377f8bd81727': 'OREL',
#  '0f78994055719622b40b6cb34e99bbdc': 'MOSCOW',
#  '0f8134688ef3e8d0924c9bd6c0afd69f': 'MOSCOW',
#  '0f89053dd087e669c38dcc4b5bebe094': 'SAMARA',
#  '0f9004ec2fb79941326b88318933fa26': 'MOSCOW',
#  '0f9b55a85c229d2b3e83dc2f4793cd54': 'TOLYATTI',
#  '0fa6e573f02c1419e535f1369276e823': 'SHEKSNA',
#  '0faee8d81c8290e0cf096ce405e1cb2a': 'SANKT-PETERBURG',
#  '0fb35218a179bd90fde7da5006aab976': 'SANKT-PETERBURG',
#  '0fb3780bd3ec55a18f94e594603b5afa': 'EKATERINBURG',
#  '0fb4e66b0030fefd97904a214949ef47': 'PETROZAVODSK',
#  '0fb50bbfcc6f941baae72fab9abc715b': 'KRASNODAR',
#  '0fbdb2fa2b47e4aef63274f7b5eb39f2': 'VOLZHSKIY',
#  '0fbe4ab55ea9ff8dd8331acec6a72adb': 'IVANOVO',
#  '0fc12de044a7ac52a7a44dfe9c1ab5ed': 'SANKT-PETERBURG',
#  '0fd1cbb537c03feb8ff11bdff0b8e28b': 'MOSCOW',
#  '0fd34a63a68ac259d4a8bfc41653b25a': 'KRASNOYARSK',
#  '0fde07d519a788b9e8343a17d9e86897': 'SANKT-PETERBURG',
#  '0fdefc46f6092d8679b6d12809a3779b': 'YAROSLAVL',
#  '0fe3360a0421ce0c2a4c32089f8e811c': 'SANKT-PETERBURG',
#  '0fe8f27aa6810628f12fc4c9671595af': 'IRKUTSK',
#  '0feff96d9e16153eee4f4d66b1b96ec7': 'OMSK',
#  '0ff38260f20cfe55c25d0f5a03638491': 'SYKTYVKAR',
#  '10011a1cdd7e4601173edbf738e75c68': 'VOLZHSKIY',
#  '10035931eb4718ffbdc17a09aadeffae': 'MOSCOW',
#  '100bbd01b86214fb268157571995a791': 'BRYANSK',
#  '100ebf0daf61caca9b9f76359e659436': 'MOSCOW',
#  '10138a8c75d019c9131a697027959b70': 'SANKT-PETERBURG',
#  '10146179a4b47211f42258c49f266124': 'MOSCOW',
#  '101c938589d3787721e9767dc4eb6eb3': 'MOSCOW',
#  '1020add6d089bcce76047b582eaada46': 'SAMARA',
#  '1022fedabdfdc3e34c2687e2e4d99008': 'MOSCOW',
#  '1024d7efa097502baff3f2825a1886c7': 'KLIMOVSK',
#  '1029535bb5ac306b3e85be11645ff3bc': 'SANKT-PETERBURG',
#  '1032074adc37eaf3cd48899fbce0cd38': 'BRYANSK',
#  '103642416f78320276e0f90c2d91f78b': 'SANKT-PETERBURG',
#  '103b539e6fecff4e1b6252e4e77edf50': 'MOSCOW',
#  '103e319f851420ae8e3de6feaf9a8a57': 'KALUGA',
#  '104d325f641c325a146bd62d6b6d3755': 'NOVOSIBIRSK',
#  '1050907af4e162bc578a7731455615fd': 'MOSCOW',
#  '10535bd7924ec652d9c1bfe16ecf3162': 'LOBNYA',
#  '1055186551e63c948f50432734cde781': 'MOSCOW',
#  '1058c8297a1794fedec382258191fd96': 'SANKT-PETERBURG',
#  '105bda47c69777ad2b6c68e9fd43e3a3': 'ROSTOV',
#  '105c479a82e8d20b5c91cd3346d80ee6': 'UFA',
#  '105f12059680ae7f4e98d3f8ff1a24af': 'MOSCOW',
#  '10690c3af5536360a88432cfc66a5f71': 'PUSHKINO',
#  '106c04fa356e7d11da7b6593da36078a': 'SANKT-PETERBURG',
#  '1070d9d9c47fac1ff77200a23ab30f04': 'KRASNOGORSK',
#  '10722bb1a87796608b6fa84776006993': 'MOSCOW',
#  '107438c417537864ae9433cc999567f1': 'SAMARA',
#  '1077d6b87ff777fd9b84f273435ee24f': 'TYUMEN',
#  '107ceac444d4f8f1fc43b3a1299099e1': 'SANKT-PETERBURG',
#  '1081582a2c4e393f28fb62c7b875ef72': 'MOSCOW',
#  '108ab015b1ad5f3f3ea4a45a48e0d747': 'SANKT-PETERBURG',
#  '10920dbcbf34d451c1ff7176527e74a1': 'BARNAUL',
#  '109d709dc904ad967647efd6af172324': 'SANKT-PETERBURG',
#  '109d811372b1e09cb037c24831d67d88': 'SURGUT',
#  '10a05ad6fff48661131ad96650d7c1a6': 'KHIMKI',
#  '10a25eb2af4812e78ea431d9c0bf66f1': 'MOSCOW',
#  '10a31a0f47d1923c8c88311e617a945c': 'MOSCOW',
#  '10a4a461f56af9dc8ab75122f4883854': 'SANKT-PETERBURG',
#  '10a56250a267f5d4d5c7b8ae3892148e': 'SURGUT',
#  '10a701be95c8afb700c1abbd6d38a225': 'OMSK',
#  '10a94ca939eec2252a441055c3101e6e': 'CHEREPOVETS',
#  '10ae74e86a4da98f6651bb4f56cc8598': 'ROSTOV',
#  '10b9fe5ece6bb437b7a3c2c0f70d1456': 'MOSCOW',
#  '10c2a25df220daffaf09ae599a881d05': 'MOSCOW',
#  '10cc3358d4d67d4057d76d4afba1f9f2': 'EKATERINBURG',
#  '10cc72405c1f491e3bdbf95bc8ddf19f': 'EKATERINBURG',
#  '10ccb2536d5ebb7e27c295e0cc96a0b9': 'MOSCOW',
#  '10ce9cc7507c81ae2cb722c805aa8ec4': 'NOVOSIBIRSK',
#  '10d158d5ffc39e529b10f82d217ec12e': 'YAROSLAVL',
#  '10daa267c01f2af8d3df9a1df8ce526f': 'MOSCOW',
#  '10dcd7b415c8db012118f5d0a5aaa5c8': 'ENGELS',
#  '10e3a63f687458a5e22c3ff525d20ac9': 'MOSCOW',
#  '10e5820642cad5a4270b6124d96b6db5': 'TULA',
#  '10e8ea63b6faf046e65221be19957d95': 'SANKT-PETERBURG',
#  '10eac5fefe7f3f38b2eb8e73bbae6c83': 'NOVOROSSIYSK',
#  '10f02be9054d62543ead28a2a1344fbf': 'MOSCOW',
#  '10f08a6300ed07c9dddc5af98d5cec24': 'EKATERINBURG',
#  '10f1b60b032e4ae4c4ada7b875952c96': 'MOSCOW',
#  '110b39c720f3b949775a9ddd30a1b80b': 'SANKT-PETERBURG',
#  '111c70c29bedf266da7d42d816bfb238': 'SANKT-PETERBURG',
#  '11230a8ad26c4b4ff2ba9093ab72368f': 'MOSCOW',
#  '112330b87abb439a89373d26acbc449a': 'MOSCOW',
#  '11245ef57d440abe59688b04e21f07f0': 'YAROSLAVL',
#  '11280e966ffed5faf7443b584330eab1': 'MOSCOW',
#  '113281b359cb5ebe0e330b85888333fc': 'KRASNODAR',
#  '11347449852b94501bb5df1e20ef95a3': 'MOSCOW',
#  '113484b8dee70c3b7a5c065f893ae015': 'MOSCOW',
#  '1134c6df06ea1f805bff378f1dcc03fa': 'MOSCOW',
#  '1138dcd1e0a41e2747d7f404e018ef3b': 'MOSCOW',
#  '113ca69d6d8d90e82c4e5662f82e8db8': 'MOSCOW',
#  '11461ebc29042899cf88cbbf80ca03b9': 'SANKT-PETERBURG',
#  '11463f6463ffb311129ae29c6afc034c': 'ANAPA',
#  '1146abda42287430d8bd3f6678341a60': 'OMSK',
#  '1147c5cd8250ae56442eb7ef2fbb7cd7': 'CHEREPOVETS',
#  '11519b4a650cf6b2a06e9380f0893d4f': 'SANKT-PETERBURG',
#  '1167a7d8e471a9c7788ff0ba4d87f58b': 'MOSCOW',
#  '116aff5db8d1d3a3188034697c15ce91': 'ODINTSOVO',
#  '1173fd89180c0ac956fe0dd262a75628': 'SANKT-PETERBURG',
#  '117f9eebb50a97be44925d26f79aee66': 'SANKT-PETERBURG',
#  '1188db5a2988e4a22ba55a45c8373974': 'MOSCOW',
#  '118ecd10806b1367c2d11153ba2355c3': 'SAMARA',
#  '119402a673f68f07f1a6b166bf2d6541': 'MOSCOW',
#  '1197ec104f8501df0feaaf69f8115653': 'MOSCOW',
#  '11a0ee4df9c11c4b08ab5d164966c7a8': 'MOSCOW',
#  '11a3364ded7f106788093a09ef7a00c0': 'SANKT-PETERBURG',
#  '11a57a82bef9c93eb40c933dedd925a8': 'KHIMKI',
#  '11af1ee014fa29a30919927ad86a8faa': 'SAMARA',
#  '11b4a39435434f639ee3c7c1cb788bd1': 'YAROSLAVL',
#  '11bb016b2838b3104a4d454fae23de43': 'MOSCOW',
#  '11c002dfc98f09ff071153da1dfce669': 'SANKT-PETERBURG',
#  '11c2050a782b04a400c329d16911f886': 'SANKT-PETERBURG',
#  '11c618f246dc48e751f4ef3df1e8d0d9': 'CHELYABINSK',
#  '11cef067f67563c5e8b8fa76fad1f8bc': 'MOSCOW',
#  '11d3a437b713065d954ab718eb71798a': 'SURGUT',
#  '11e3dd893c47335ef558d77ce1baf654': 'MOSCOW',
#  '11e4cb90db2d18259ad6c672aa678d89': 'MOSCOW',
#  '11f554eaac5a08b01ef2756248caa372': 'KRASNODAR',
#  '11f8720f071ee4b13b2202db7a07e4da': 'SANKT-PETERBURG',
#  '11f8d62c3b837d11f28a624efcee06ab': 'SANKT-PETERBURG',
#  '11fa5021984bd653d4382b685a5e9f5a': 'MOSCOW',
#  '11fb8751ff881a50b39f676369a12443': 'EKATERINBURG',
#  '1203ccaac6624f809501a5e0777abde4': 'MOSCOW',
#  '120584580038018b65bfb2bf1b37669b': 'SANKT-PETERBURG',
#  '120fa11070f063f5cac370c1f960892d': 'MOSCOW',
#  '12207e75d26fe8ea7c0fbcdfb4da3e77': 'MOSCOW',
#  '12236e739e8233da70dcae4ea6ad595a': 'MOSCOW',
#  '1225e58e9845604c42b77fd17bd99933': 'SANKT-PETERBURG',
#  '12266b4303e6f9e46045286a8a82efc8': 'SOCHI',
#  '122a27b0b62054f3cdf582d5156d30ff': 'MOSCOW',
#  '122b27ab7365029f83d258951627af18': 'MOSCOW',
#  '122f2986b1328d228772c8f0c535612b': 'KEMEROVO',
#  '1232ffdf5679cd4957d6575b11690f00': 'SERPUKHOV',
#  '123b4e64fce19761f3ccb3e58d990d18': 'MOSCOW',
#  '1246c474055da4f0ff4146e7e92921cd': 'SVETOGORSK',
#  '12480c6c337d5bf9fe3628f790220f3d': 'MOSCOW',
#  '124d00c7d7f9b06e4931a1b77fd8f3a7': 'EKATERINBURG',
#  '125fbdc441f1a05133de8838a89192a0': 'MOSCOW',
#  '12653ee71304f0f5ceebb691ea5b423d': 'MOSCOW',
#  '1274786c8824bd59eb46e50edddce450': 'SANKT-PETERBURG',
#  '127599b4e41b736e82638b91b5bc10f1': 'MOSCOW',
#  '12827220c858d8b54c8196fcb5466d2f': 'SANKT-PETERBURG',
#  '128d81c4901e5d3fa8f00220046312bd': 'EKATERINBURG',
#  '128e37d433cebf0d1a70d1063863dfcf': 'NIZHNIY NOV',
#  '12917a1dc1525c525df058676ce419c3': 'MOSCOW',
#  '12948d3d54b77e6dd04ad5ee8ce49a3e': 'MOSCOW',
#  '1294a4d48646a5c668a5e35308aaa008': 'SANKT-PETERBURG',
#  '129aeeb437b874a2ee0a5046c77c210d': 'BALASHIKHA',
#  '12a923cc3d19925bb85fba9ab26efb63': 'MOSCOW',
#  '12abe51f49d81ecadbfd3519e0df258e': 'KURSK',
#  '12aca2fc97031372eeffab62da4a5248': 'PUSHKINO',
#  '12afebdcd50e19e056abdc9aeeaf44fb': 'SANKT-PETERBURG',
#  '12b9276f08f76225df2c40eb6b1873cf': 'SANKT-PETERBURG',
#  '12bababe210d86eac3de06aaba575211': 'SANKT-PETERBURG',
#  '12c8059cfe4e04bdf114794aa91b4304': 'NOGINSK',
#  '12ccf9c082084cffb674c7a91a6d2366': 'MOSCOW',
#  '12ce0c31ae63c747aa9c0090ad315999': 'SHEBEKINO',
#  '12cf2b51beee75a11dc618d539bc067b': 'SANKT-PETERBURG',
#  '12d4688011331c48a28a0b2e3d890d0d': 'SANKT-PETERBURG',
#  '12dc53573177fbfe3679f28329176db3': 'KURSK',
#  '12dd45a7d45413d750983897e189e7dd': 'ROSTOV',
#  '12dfcd7a82d1c1c215c1865a0c14e302': 'SANKT-PETERBURG',
#  '12ec20b4be8b0f1adcf49210a65a83f0': 'SANKT-PETERBURG',
#  '12ed790448ecca3b04493fda1a35b7ed': 'MOSCOW',
#  '12eef1d6fa0b96debc7f7913e3e4a662': 'MOSCOW',
#  '12f11c29bd24d3c2192ba2e44fa94ac9': 'KAZAN',
#  '12f667096029b2b7f076beca9980937a': 'MOSCOW',
#  '13005ba6c93c79e853ca5e59e188111f': 'UFA',
#  '13104e407f605400138dbf2328ad1cf6': 'NOVOSIBIRSK',
#  '131259f07d21a25394f65e9f2b17e8ea': 'SANKT-PETERBURG',
#  '13148c85cb5c817a2d90c8db24f8163b': 'MOSCOW',
#  '1318989be2ae7840dbe3726d99ace8e4': 'VORONEZH',
#  '131e56a3099aac28c6a7555e8d640f27': 'SANKT-PETERBURG',
#  '131fad0c58e1ace074db96de1f1a3f86': 'MOSCOW',
#  '1324f671a415f567106aab397a9e03bb': 'MOSCOW',
#  '132e3d8b1b123a27e78a4134c3c5530f': 'IVANOVO',
#  '1334d9d8e7ae14cde42ec3cb06cb1402': 'MOSCOW',
#  '1337126ba1a294a9a6caa01174d28dc2': 'SANKT-PETERBURG',
#  '133852919fe1bbaf54ded3356c5f797d': 'MOSCOW',
#  '133d8d569e46ac0eef7fa80174da8619': 'SYKTYVKAR',
#  '134c3a728f53d9a80ab8bbfd873b39de': 'SANKT-PETERBURG',
#  '134e2467aaa058ab40cc82cd3bda3d1f': 'YALUTOROVSK',
#  '1350baedc6c3f4df4f0d8c8c04bcba3e': 'SARANSK',
#  '1355a67d09c0fed900694921f18d3d47': 'SANKT-PETERBURG',
#  '13599c353ad046fcd3bb22f2b619959d': 'MOSCOW',
#  '136631162cd75b26a2dabd7c270953a6': 'SOCHI',
#  '13759e760b06c22a26cb8dc3fc300bf7': 'MOSCOW',
#  '137836f37ca0f096fa715229b3bd7150': 'KAZAN',
#  '137c2a16fda1e34edfbbd4b82b007111': 'LIPETSK',
#  '137f3e2517cefef331e19c5ac594b55f': 'EKATERINBURG',
#  '1387c4c09326ff6630781d307c208501': 'SANKT-PETERBURG',
#  '138fe9db3baf0f093798125230d099c8': 'SANKT-PETERBURG',
#  '1399d4573f9ddc1b4a68d8e329518dd1': 'KAZAN',
#  '139c58108d0fbbb07483ef92506ec7d8': 'MOSCOW',
#  '13a09087c07503db3af09e94b404a041': 'TYUMEN',
#  '13aab017d71def36064cca312a610f92': 'MOSCOW',
#  '13b83ba2e1a886537fc7ee706604325d': 'NOVOSIBIRSK',
#  '13bb55c46a2f5a2912eba0ba6679f26f': 'MOSCOW',
#  '13c42d3caa8b0506c0f2b0abfff2a830': 'IVANTEEVKA',
#  '13cb276917a255bfb288d97d0150f9e7': 'MOSCOW',
#  '13ccbdac4db6600f020d5606c86d2924': 'MOSCOW',
#  '13cd605c8b86f440e1b051e5a29bd6df': 'KIROV',
#  '13d682f6e0cd03dd52c4d6030a3e1cc4': 'MOSCOW',
#  '13ded4e7b1affa567389ae627f043626': 'VOLGOGRAD',
#  '13ebcd8102b0f08e6dba3f5252538883': 'MOSCOW',
#  '13ee9fddb1ec0a6dc5fb59bae5241a1a': 'TYUMEN',
#  '13f9bdbf286f32d8845471293d8e004c': 'KRASNOYARSK',
#  '13fa3ea43896da0c0ca950b5d8f76790': 'BALASHIKHA',
#  '13fc63144b7b8ef775f953cb316e66c2': 'KAZAN',
#  '1403da71ece5fdabb169988b564fa3a4': 'SANKT-PETERBURG',
#  '14089600c356253a9fd0ef86a95b2ead': 'MOSCOW',
#  '140a7b1f6480b07e976f5df3bd5c4f89': 'CHEREPOVETS',
#  '140def04edc7e13bc596007fd32c8edc': 'SMYSHLYAEVKA',
#  '14141e112cf836c5332dc7c199007bec': 'SOCHI',
#  '141427c34d368c6bea5bddcd3d8dc75a': 'SANKT-PETERBURG',
#  '141763978ab15665761384ae2fb0f0a8': 'VORONEZH',
#  '141d7f3eb21a580222ee55e834678930': 'ZHELEZNODOROZ',
#  '142671e38daa7492785db0057cc77cfc': 'OMSK',
#  '142e8f474a939db88b7f16efac49815d': 'EKATERINBURG',
#  '143749694f8e61308c23c37678bf2ecd': 'NIZHNIY NOV',
#  '143d6410da04f2bd88e4424e23a21ac5': 'MOSCOW',
#  '144c263b3dc5e6c895740f47d72aa9c2': 'SANKT-PETERBURG',
#  '14591148787e038d61787404ec8aff58': 'MOSCOW',
#  '14595b1cadfa3e6460d9e8f666b0d353': 'MOSCOW',
#  '145b6113703a765d693dfd6e5ede9755': 'MOSCOW',
#  '145ceaa5079d39ec175920275c251c69': 'MOSCOW',
#  '145dd478168fc2c8813bd36c388aae46': 'EKATERINBURG',
#  '146a8cb2ecb0f21c2fe6a3554cbdcb4e': 'KLIMOVSK',
#  '146f3f8a00ed2662af8c41e1978b04cb': 'SANKT-PETERBURG',
#  '1478dfed4b00da24755cdf65eba65f3e': 'MOSCOW',
#  '148daa946701c97540e7b165aedb0e06': 'CHEREPOVETS',
#  '1490f79442852c0c8a73636a919e5fe3': 'SANKT-PETERBURG',
#  '1491e028edd9c5eb89071ae2f2a7c8b6': 'MOSCOW',
#  '14925c9962ff05f7db97f2cf63723e1e': 'SANKT-PETERBURG',
#  '149c38ff3d13a0be77432791e33801ad': 'MOSCOW',
#  '149c6e2f404661875ad07849451de72a': 'SURGUT',
#  '14a57363666668b4e4994a99ca83a7d4': 'KALININGRAD',
#  '14b7a7c8e39c69fa0b54c1f8823bafa9': 'KIROV',
#  '14bf7d03f538b946dbf19c41d934c70e': 'YAROSLAVL',
#  '14c9396e14d6a91c36a2ccaa0dd12cf8': 'SANKT-PETERBURG',
#  '14d278de9739a32311d528c2fd773f46': 'LIPETSK',
#  '14d30c46f9cf8cbfe36c73ad51296ad2': 'MOSCOW',
#  '14d320a4a84f4b884b4fb60cda4aa4a6': 'MOSCOW',
#  '14d5172fe318600f62063bc93e4bb192': 'SANKT-PETERBURG',
#  '14da2cd33284f6f472005dc35696e617': 'SANKT-PETERBURG',
#  '14db5ebf237649b73e8da17fe684849c': 'SANKT-PETERBURG',
#  '14e0c76eec6dc3ebb9c141ee447a2b6a': 'MOSCOW',
#  '14ea07ae9a156d143f05ff85beaad1a9': 'SANKT-PETERBURG',
#  '14eaa263cc314f6bf337c79ba01083e1': 'SANKT-PETERBURG',
#  '14ee4fdffaf6519810e2a3841a775d23': 'SANKT-PETERBURG',
#  '14eec908e1e2eee88d20be014aee2305': 'MOSCOW',
#  '1504aeaccce4fab847131e84ab2adbf3': 'KLIN',
#  '15075298fdb0355c05182de89e766ac3': 'LIPETSK',
#  '1507d30b64ceb00f40097068b121b7ca': 'MOSCOW',
#  '1524d66c5fdb3ddb82ae3dc26cc7aaac': 'SANKT-PETERBURG',
#  '1526de261100a7aff264fc017653be94': 'SYKTYVKAR',
#  '1527ac323fcbf77c63e6831daed6f9fc': 'MOSCOW',
#  '152844352959d431aa26d583d30976d9': 'SANKT-PETERBURG',
#  '152dce44add94e4690b5e8e2cd6d7363': 'SANKT-PETERBURG',
#  '152f7d19ebe006d767e70c8a163b41e7': 'SANKT-PETERBURG',
#  '1530796da6b5200091692ac2dbf7e84f': 'CHEREPOVETS',
#  '15318d225fb26e434f4de0b9f3c8c67e': 'SANKT-PETERBURG',
#  '1531e9b90818ecc0a2ced5ef2b5e843c': 'ANAPA',
#  '153306fe9cdcc3721fe2752d9b02d7bb': 'SANKT-PETERBURG',
#  '1535d765ede6f56d12419a4ec35d9217': 'CHEREPOVETS',
#  '153967421a7edba1fb169114e0ed8377': 'MOSCOW',
#  '1540b12cd02805f3c27d3d16a3f29308': 'MOSCOW',
#  '1543f949882a00e6ff085f1be3a93a7f': 'MOSCOW',
#  '154ee307bbc8146ee5487fc4a4fb00cb': 'SANKT-PETERBURG',
#  '154f973dbd6b0c1f000d36bfdfe8e0d2': 'MOSCOW',
#  '154fab889eb80b4042cbeb7b6e7a708e': 'SANKT-PETERBURG',
#  '15544687b6e54843c0634e3449b4a5cc': 'MOSCOW',
#  '155a05be2e04adc74dfd7a14ca416fbf': 'SERPUHOV',
#  '15666d91bdf6ad6736b9a5fb8e4a659d': 'KHIMKI',
#  '1569486d48c5edc1559b21e2288daa54': 'VSEVOLOZHSK',
#  '156980c0ce1a20e00c43bc4505da155e': 'SANKT-PETERBURG',
#  '156c7603263e359c4651dc54b7bcaa79': 'MOSCOW',
#  '158224a0b7f31fad330c9fdd30974b7f': 'SANKT-PETERBURG',
#  '158f37949a9444f65b883c41ba11cfa2': 'MOSCOW',
#  '15939360b5ee357b87c71925e4b6af4f': 'SANKT-PETERBURG',
#  '1595dd437c2f8cbac9774adea6d10b01': 'OREL',
#  '159673c2adc0b2be66aa48e9f80f738a': 'ROSTOV',
#  '15975b3cddd2a8bf082591d824c20554': 'SAMARA',
#  '159bd07f919d4368ac9c0986f291b097': 'SMOLENSK',
#  '15adbe447e1b19ec53133f357e89524d': 'VOLGOGRAD',
#  '15b690f53911590f1eb22cf1e569980e': 'NOVOROSSIYSK',
#  '15b9aee63e47c44df57f4e982776dd00': 'MOSCOW',
#  '15bb285f02c4ce9db9461a4b691b9547': 'SANKT-PETERBURG',
#  '15c73c1e3bcdf8f618ead8f72c6e476c': 'SANKT-PETERBURG',
#  '15c89b86a5ee85dcf20ab19788f3f72f': 'MOSCOW',
#  '15cf1a84cea25aab73bb10b96aef43b0': 'MOSCOW',
#  '15d1064e4f95f3efcbaef2d610fe6b1c': 'MOSCOW',
#  '15d33e620d0724a63a840b0763a7d1dd': 'SANKT-PETERBURG',
#  '15dbb19dce87cb6bfdab9471ed5cb2d0': 'TYUMEN',
#  '15e4fa0604eb368e7881cfef60e2e8ec': 'NOVOSIBIRSK',
#  '15e696ee7f64891007012c2c6ff4080b': 'ANAPA',
#  '15eb50a050ea66296514d04e06d83dcd': 'PETROZAVODSK',
#  '15f96285edff7f7d4e1dc6ca83ec1416': 'MOSCOW',
#  '15fad088ecd8dcc606e3e5a29b84ce7e': 'SANKT-PETERBURG',
#  '1602075336169c1e1ca183742c037723': 'MOSCOW',
#  '16066baceb831e551ae699715b91d590': 'SANKT-PETERBURG',
#  '160fd9f0cb64d4a825f5b5f7e94f2f3e': 'SANKT-PETERBURG',
#  '16100b9eac6fddc982ddf1958ee119cb': 'VORONEZH',
#  '1615b79378cd4c9f11773e93cac1126a': 'MOSCOW',
#  '1618acbb857169cea0f4c8bd77622413': 'SANKT-PETERBURG',
#  '1618c2112d9100fc5d7c5ee698a34f46': 'KALININGRAD',
#  '161b8e100b3caff827b2c71cecb96c5c': 'MOSCOW',
#  '16207b6fc39380eef0a412400cd3dc87': 'KAZAN',
#  '16214c77b6f97f30cb37286c6139c418': 'CHELYABINSK',
#  '16255188287858c08a69051524edae79': 'SANKT-PETERBURG',
#  '1626afe7ff777e3084dae6a861b9c882': 'SARATOV',
#  '1628332bfab1b3ee1fe82f9e523742fd': 'MOSCOW',
#  '1628f34924ab0408d49f7c3c2f59478f': 'SANKT-PETERBURG',
#  '162966297a18184540f15f4c0a7bb892': 'MOSCOW',
#  '162c6117f13c168fc24bc608f265f652': 'SANKT-PETERBURG',
#  '162d5f4ea7afd6fa55075baf2b054818': 'EKATERINBURG',
#  '163946b8edb367a447c963bcbba64809': 'NIZHNIY NOV',
#  '1640c95ec255180ae8c891eb2c754b4b': 'SARANSK',
#  '1642ccaec2ded5c85da2b8ee59008251': 'MOSCOW',
#  '1643144273a5165684e18af934c75a12': 'MOSCOW',
#  '1647e82b0808b17ceaeccc56c0026538': 'MOSCOW',
#  '16536ecd92f01fb22a1bbbccda2b60eb': 'EKATERINBURG',
#  '1654852a696df7310d0eecb1e4939b17': 'VORONEZH',
#  '165af3ab797a99e2875835e0f65ea45c': 'MOSCOW',
#  '166372ceb1548fe1f31f00a4ce63b302': 'CHEREPOVETS',
#  '166421d70c9685a38929122ebf4d613a': 'SANKT-PETERBURG',
#  '166ca5c6c5882a5afeb43c3d0ebfd79c': 'SLANTSY',
#  '166ff6267bd6c683768dee0c54efda5b': 'MOSCOW',
#  ...}

# %%
def filter_city(cust, city, map_customer_city) :
    if map_customer_city[cust] == city :
        return 1
    else :
        return 0

# %%
df['filter_city'] = df.apply(lambda x : filter_city(x['customer_id'], x['city'], map_customer_city), axis = 1)

# %%
df = df[df['filter_city'] == 1]

# %% [markdown]
# #### <font color = 'blue'> По каждому клиенту делаем кластеризацию MeanShift() и берем 2 самых больших класса. Дальше нам надо как-то раскидать их на дом и работу. Если считать, что больше транзакций совершается около дома, то скор будет ~0.24, если же около работы, то скор ~0.26

# %%
# %%time
lst = []
for cust in log_progress(df['customer_id'].unique(), every = 1) :
    df_tmp = df[df['customer_id'] == cust]
    #print(df_tmp)
    if df_tmp.shape[0] < 2 :
        lst.append([cust, df_tmp['lat'].values[0], df_tmp['lon'].values[0], df_tmp['lat'].values[0], df_tmp['lon'].values[0]])
        continue
    ms = MeanShift(bandwidth = 0.005, cluster_all = False)
    ms.fit(df_tmp[['lat', 'lon']])
    lst.append([cust, df_tmp[ms.labels_ == 0]['lat'].mean(), df_tmp[ms.labels_ == 0]['lon'].mean(),
                          df_tmp[ms.labels_ == 1]['lat'].mean(), df_tmp[ms.labels_ == 1]['lon'].mean()])
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=9997)))
# Wall time: 23min 44s

# %%
pd.DataFrame(lst).rename(columns = {0 : '_ID_', 1 : '_WORK_LAT_', 2 : '_WORK_LON_', 
                                  3 : '_HOME_LAT_', 4 : '_HOME_LON_'}).fillna(0).to_csv('res.csv', index = False)

# %% [markdown]
# #### <font color = 'blue'> Можно улучшить если по уму раскидывать результаты кластеризации на дом и работу, используя например mcc</font>
